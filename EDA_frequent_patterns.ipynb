# %% [markdown]
# <a href="https://colab.research.google.com/github/RozitaAbdoli/credit_default_mining/blob/main/EDA_frequent_patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## EDA: Association Rule Mining using Frequent Pattern Growth Algorithm
# * An association rule has the form LHS (left-hand side) => RHS (right-hand side)
# * LHS U RHS is called an itemset
# * The “support” or prevalence of the rule is the frequency of occurence of an itemset in a dataset/database for it to be considered a “frequent itemset” or a “frequent pattern”.
# * The “confidence” or strength of the rule = support(LHS U RHS)/support(LHS). Or the probability that the items in RHS will occur given that the items in LHS have occured.
# * Here, support threshold is set at 1000, and confidence threshold is set at 0.8.

# %%
#install and import necessary libraries
# !pip install pyfpgrowth 
import os
import pyfpgrowth
import pandas as pd
# Out:
# Requirement already satisfied: pyfpgrowth in /usr/local/lib/python3.7/dist-packages (1.0)

# %%
#Import Drive API and authenticate
from google.colab import drive
#Mount Drive to the Colab VM
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Load the dataset into pandas DataFrame
df = pd.read_csv("/content/drive/MyDrive/Capstone_project/v2_credit_default.csv")

# %%
# keep the categorical attributes. The numeric attributes can be binned/converted to categorical and added to this list too.
df2 = df[['SEX', 'EDUCATION', 'MARRIAGE', 'Repay_Sept',
       'Repay_Aug', 'Repay_July', 'Repay_June', 'Repay_May', 'Repay_Apr','Default']]

# %%
# turn off chain assignment warning for the next cell
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Renaming some of the columns so it's easier to understand association rules
df2['SEX'] = df2['SEX'].replace({ 1: 'Male', 2: 'Female'})
df2['EDUCATION'] = df2['EDUCATION'].replace({1:'Graduate School', 2:'University', 3:'High School', 4:'Others'})
df2['MARRIAGE']= df2['MARRIAGE'].replace({1:'Married', 2:'Single', 3:'Others'})
df2['Repay_Apr'] = df2['Repay_Apr'].replace({-2:'Apr_not_used', -1:'Apr_duly_payment', 0:'Apr_revolving_credit', 1: 'Apr_late_1month', 2: 'Apr_late_2months', 3: 'Apr_late_3months', 4: 'Apr_late_4months', 5: 'Apr_late_5months', 6: 'Apr_late_6months', 7: 'Apr_late_7months', 8: 'Apr_late_8months'})
df2['Repay_May'] = df2['Repay_May'].replace({-2:'May_not_used', -1:'May_duly_payment', 0:'May_revolving_credit', 1: 'May_late_1month', 2: 'May_late_2months', 3: 'May_late_3months', 4: 'May_late_4months', 5: 'May_late_5months', 6: 'May_late_6months', 7: 'May_late_7months', 8: 'May_late_8months'})
df2['Repay_June'] = df2['Repay_June'].replace({-2:'June_not_used', -1:'June_duly_payment', 0:'June_revolving_credit', 1: 'June_late_1month', 2: 'June_late_2months', 3: 'June_late_3months', 4: 'June_late_4months', 5: 'June_late_5months', 6: 'June_late_6months', 7: 'June_late_7months', 8: 'June_late_8months'})
df2['Repay_July'] = df2['Repay_July'].replace({-2:'July_not_used', -1:'July_duly_payment', 0:'July_revolving_credit', 1: 'July_late_1month', 2: 'July_late_2months', 3: 'July_late_3months', 4: 'July_late_4months', 5: 'July_late_5months', 6: 'July_late_6months', 7: 'July_late_7months', 8: 'July_late_8months'})
df2['Repay_Aug'] = df2['Repay_Aug'].replace({-2:'Aug_not_used', -1:'Aug_duly_payment', 0:'Aug_revolving_credit', 1: 'Aug_late_1month', 2: 'Aug_late_2months', 3: 'Aug_late_3months', 4: 'Aug_late_4months', 5: 'Aug_late_5months', 6: 'Aug_late_6months', 7: 'Aug_late_7months', 8: 'Aug_late_8months'})
df2['Repay_Sept'] = df2['Repay_Sept'].replace({-2:'Sept_not_used', -1:'Sept_duly_payment', 0:'Sept_revolving_credit', 1: 'Sept_late_1month', 2: 'Sept_late_2months', 3: 'Sept_late_3months', 4: 'Sept_late_4months', 5: 'Sept_late_5months', 6: 'Sept_late_6months', 7: 'Sept_late_7months', 8: 'Sept_late_8months'})
df2['Default'] = df2['Default'].replace({ 0: 'no_default', 1: 'default'})

# %%
## Convert df2 to list of lists, and look at the first 2 lists (first 2 rows).
df2_list = df2.values.tolist()
print(df2_list[0:2])
# Out:
# [['Female', 'University', 'Married', 'Sept_late_2months', 'Aug_late_2months', 'July_duly_payment', 'June_duly_payment', 'May_not_used', 'Apr_not_used', 'default'], ['Female', 'University', 'Single', 'Sept_duly_payment', 'Aug_late_2months', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Apr_late_2months', 'default']]

# %%
patterns = pyfpgrowth.find_frequent_patterns(df2_list, support_threshold = 1000)

# %%
rules = pyfpgrowth.generate_association_rules(patterns, confidence_threshold = 0.8)

# %% [markdown]
# #### Some interesting association rules picked from the association rules below:
# * ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['no_default'] 0.8676880222841226
#
# ~87% of females that are not using their credit in the previous 6 months are non-defaulters. This is expected.
# * ['Apr_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'Male', 'May_revolving_credit', 'University'] --> ['no_default'] 0.8115758343895226
#
# ~81% of males with Bachelor's degree that are using their revolving credit from April to July are non-defaulters.
# * ['Apr_revolving_credit', 'Female', 'July_revolving_credit', 'June_revolving_credit', 'Married', 'May_revolving_credit', 'University'] --> ['no_default'] 0.8515881708652793
#
# ~85% of married females that are using their revolving credit from April to July are non-defaulters.

# %%
# Now to make the outputted rules look nicer:
for antecedents, consequents in rules.items():          #my note: for keys, values in dictionary.items():
    antec_list =[]
    conseq_list =[]
    for a in antecedents:
        antec_list.append(a)
    for c in consequents[0]:
        conseq_list.append(c)
    print(antec_list, '-->', conseq_list, consequents[1])
# Out:
# ['Aug_late_2months', 'July_late_2months', 'May_late_2months'] --> ['June_late_2months'] 0.9617097061442564
# ['Aug_late_2months', 'June_late_2months', 'May_late_2months'] --> ['July_late_2months'] 0.9694793536804309
# ['Apr_late_2months', 'July_late_2months', 'June_late_2months'] --> ['May_late_2months'] 0.9496021220159151
# ['Apr_late_2months', 'July_late_2months', 'May_late_2months'] --> ['June_late_2months'] 0.9572192513368984
# ['Apr_late_2months', 'June_late_2months', 'May_late_2months'] --> ['July_late_2months'] 0.8014925373134328
# ['Apr_late_2months', 'June_late_2months'] --> ['May_late_2months'] 0.9403508771929825
# ['July_late_2months', 'Sept_late_2months'] --> ['Aug_late_2months'] 0.9367396593673966
# ['June_revolving_credit', 'Sept_late_2months'] --> ['May_revolving_credit'] 0.8841033672670321
# ['May_revolving_credit', 'Sept_late_2months'] --> ['Apr_revolving_credit'] 0.8527298850574713
# ['Apr_revolving_credit', 'Sept_late_2months'] --> ['May_revolving_credit'] 0.8539568345323741
# ['June_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used', 'July_not_used'] 0.9937275985663082
# ['July_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used', 'no_default'] 0.8658119658119658
# ['Apr_not_used', 'July_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used', 'May_not_used'] 0.9941463414634146
# ['Apr_not_used', 'June_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used', 'July_not_used', 'May_not_used'] 0.9951171875
# ['July_not_used', 'June_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'Sept_not_used', 'Single'] --> ['no_default'] 0.8686305732484076
# ['Apr_not_used', 'Aug_not_used', 'Sept_not_used', 'Single'] --> ['May_not_used'] 0.9903660886319846
# ['Aug_not_used', 'June_not_used', 'Sept_not_used', 'Single'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used'] 0.9865642994241842
# ['June_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used'] 0.9943555973659455
# ['Aug_not_used', 'July_not_used', 'Sept_not_used', 'Single'] --> ['no_default'] 0.8658119658119658
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Sept_not_used', 'Single'] --> ['May_not_used'] 0.9941463414634146
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Sept_not_used', 'Single'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Sept_not_used', 'Single'] --> ['May_not_used'] 0.9531109107303878
# ['July_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used', 'July_not_used'] 0.9951171875
# ['July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['June_not_used'] 0.9906279287722587
# ['Apr_not_used', 'Aug_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['July_not_used'] 0.9912451361867705
# ['Aug_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'Sept_not_used', 'Single'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'Single'] --> ['Apr_not_used'] 0.9640491958372753
# ['Sept_not_used', 'Single', 'no_default'] --> ['Aug_not_used'] 0.9261460101867572
# ['Aug_not_used', 'Sept_not_used', 'Single', 'no_default'] --> ['July_not_used'] 0.928505957836847
# ['July_not_used', 'Sept_not_used', 'Single', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Graduate School', 'July_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used', 'May_not_used'] 0.9934579439252337
# ['Apr_not_used', 'Graduate School', 'June_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'May_not_used'] 0.992530345471522
# ['Graduate School', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'Sept_not_used'] --> ['July_not_used'] 0.9467084639498433
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'Sept_not_used'] --> ['May_not_used'] 0.9861878453038674
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'Sept_not_used'] --> ['no_default'] 0.8634105960264901
# ['Apr_not_used', 'Graduate School', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.984375
# ['Graduate School', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'June_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used', 'Sept_not_used'] --> ['June_not_used', 'May_not_used'] 0.9934579439252337
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'June_not_used', 'Sept_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['May_not_used'] 0.9584415584415584
# ['Graduate School', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.991047448522829
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'Graduate School', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.992530345471522
# ['Graduate School', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 0.9901610017889088
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 0.992530345471522
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Apr_not_used'] 0.960252935862692
# ['Graduate School', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'July_not_used'] 0.880168776371308
# ['Aug_not_used', 'Graduate School', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 0.9430379746835443
# ['Graduate School', 'July_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['July_not_used', 'Married', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'Married', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used', 'May_not_used'] 0.9906890130353817
# ['Apr_not_used', 'June_not_used', 'Married', 'Sept_not_used'] --> ['Aug_not_used', 'May_not_used'] 0.9888475836431226
# ['July_not_used', 'June_not_used', 'Married', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'Married', 'Sept_not_used'] --> ['July_not_used'] 0.9427899686520376
# ['Apr_not_used', 'Aug_not_used', 'Married', 'Sept_not_used'] --> ['May_not_used'] 0.9807692307692307
# ['Aug_not_used', 'July_not_used', 'Married', 'Sept_not_used'] --> ['no_default'] 0.8603491271820449
# ['Apr_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.979871912168344
# ['July_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Aug_not_used', 'June_not_used', 'Married', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Married', 'Sept_not_used'] --> ['June_not_used', 'May_not_used'] 0.9906890130353817
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Married', 'Sept_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Married', 'Sept_not_used'] --> ['Aug_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Married', 'Sept_not_used'] --> ['May_not_used'] 0.9686684073107049
# ['June_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.9867021276595744
# ['Apr_not_used', 'July_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'June_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.9888475836431226
# ['July_not_used', 'June_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 0.9910952804986642
# ['Apr_not_used', 'Aug_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 0.9934640522875817
# ['Aug_not_used', 'July_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'June_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'Married', 'Sept_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Married', 'May_not_used', 'Sept_not_used'] --> ['Apr_not_used'] 0.9559748427672956
# ['Married', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'July_not_used'] 0.8697478991596639
# ['Aug_not_used', 'Married', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 0.9409090909090909
# ['July_not_used', 'Married', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'Female', 'July_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used', 'May_not_used'] 0.9958391123439667
# ['Female', 'July_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'Female', 'June_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'May_not_used'] 0.9944598337950139
# ['Female', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Female', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'July_not_used'] 0.9903703703703703
# ['Apr_not_used', 'Female', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'May_not_used'] 1.0
# ['Apr_not_used', 'Female', 'July_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'June_not_used', 'May_not_used'] 0.9968
# ['Apr_not_used', 'Female', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'May_not_used'] 0.994413407821229
# ['Female', 'July_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'Sept_not_used'] --> ['May_not_used'] 0.9897540983606558
# ['Aug_not_used', 'Female', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 0.9304635761589404
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'Sept_not_used'] --> ['June_not_used', 'May_not_used'] 0.9958391123439667
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'no_default'] --> ['May_not_used'] 0.9881812212738017
# ['Apr_not_used', 'Aug_not_used', 'Female', 'Sept_not_used', 'no_default'] --> ['May_not_used'] 0.9913249211356467
# ['Aug_not_used', 'Female', 'July_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 0.9516014234875445
# ['Apr_not_used', 'Female', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.9877300613496932
# ['Female', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'Female', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'Female', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 0.9866562009419152
# ['Female', 'July_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Aug_not_used', 'Female', 'June_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'June_not_used', 'Sept_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'June_not_used', 'no_default'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['no_default'] 0.8620245003223727
# ['Aug_not_used', 'Female', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.9968
# ['Apr_not_used', 'Aug_not_used', 'Female', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Female', 'July_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['May_not_used'] 0.9670905011219147
# ['Female', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.9920529801324504
# ['Apr_not_used', 'Female', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.9944598337950139
# ['Female', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Female', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 0.9915644171779141
# ['Apr_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'Female', 'July_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'Female', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 0.994413407821229
# ['Female', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'Female', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 0.9900859220092532
# ['Apr_not_used', 'Aug_not_used', 'Female', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 0.9910282953761215
# ['Apr_not_used', 'Aug_not_used', 'Female', 'May_not_used', 'no_default'] --> ['July_not_used'] 0.9798177083333334
# ['Aug_not_used', 'Female', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'Female', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 0.9900459418070444
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 0.9912490055688147
# ['Aug_not_used', 'Female', 'July_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'Female', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'June_not_used', 'May_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['no_default'] 0.863150867823765
# ['Aug_not_used', 'Female', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['no_default'] 0.8676880222841226
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Sept_not_used'] 0.827906976744186
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Apr_not_used'] 0.9636504253673627
# ['Female', 'July_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'no_default'] 0.8609068627450981
# ['Aug_not_used', 'Female', 'Sept_not_used'] --> ['no_default'] 0.864338866628506
# ['Aug_not_used', 'Female', 'July_not_used', 'Sept_not_used'] --> ['no_default'] 0.8609068627450981
# ['Aug_not_used', 'Female', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'Female', 'June_not_used', 'May_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Apr_not_used'] 0.950726468730259
# ['Female', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 0.9252450980392157
# ['Aug_not_used', 'Female', 'May_not_used', 'no_default'] --> ['July_not_used', 'June_not_used'] 0.9729563614013522
# ['Apr_not_used', 'July_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used', 'May_not_used'] 0.9924385633270322
# ['July_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'June_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'May_not_used'] 0.9919697685403873
# ['June_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'July_not_used'] 0.9894206549118388
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'May_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'June_not_used', 'May_not_used'] 0.992896174863388
# ['Apr_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'May_not_used'] 0.9918122270742358
# ['July_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Sept_not_used'] --> ['May_not_used'] 0.9855612482533768
# ['Aug_not_used', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 0.9347826086956522
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Sept_not_used'] --> ['June_not_used', 'May_not_used'] 0.9924385633270322
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'no_default'] --> ['May_not_used'] 0.9844582593250444
# ['Apr_not_used', 'Aug_not_used', 'Sept_not_used', 'no_default'] --> ['May_not_used'] 0.9865301724137931
# ['Aug_not_used', 'July_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 0.9515503875968992
# ['Apr_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.983271375464684
# ['July_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 0.9828234031132582
# ['July_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Sept_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'no_default'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.992896174863388
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['May_not_used'] 0.9613034623217923
# ['June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.990493435943866
# ['Apr_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 0.9919697685403873
# ['July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 0.9900367068694285
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used', 'June_not_used'] 1.0
# ['Apr_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 0.9918122270742358
# ['July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 0.9909420289855072
# ['Apr_not_used', 'Aug_not_used', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 0.9924385633270322
# ['Apr_not_used', 'Aug_not_used', 'May_not_used', 'no_default'] --> ['July_not_used'] 0.9814077025232404
# ['Aug_not_used', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 0.9905561385099685
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'May_not_used', 'Sept_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 0.9923539049699618
# ['Aug_not_used', 'July_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['no_default'] 0.8628884826325411
# ['Aug_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used'] --> ['no_default'] 0.8652380952380953
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Sept_not_used'] 0.8195760036084799
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'Sept_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Sept_not_used', 'no_default'] --> ['Apr_not_used'] 0.9623940677966102
# ['July_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['July_not_used', 'June_not_used', 'Sept_not_used'] --> ['Aug_not_used'] 1.0
# ['Aug_not_used', 'Sept_not_used'] --> ['July_not_used'] 0.9373040752351097
# ['Aug_not_used', 'July_not_used', 'Sept_not_used'] --> ['no_default'] 0.862876254180602
# ['Aug_not_used', 'June_not_used', 'Sept_not_used'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Sept_not_used'] --> ['no_default'] 0.8629173989455184
# ['Aug_not_used', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Apr_not_used'] 0.9478409576742197
# ['Sept_not_used', 'no_default'] --> ['Aug_not_used', 'July_not_used'] 0.865046102263202
# ['Apr_late_2months', 'Aug_late_2months'] --> ['July_late_2months'] 0.804147465437788
# ['Apr_revolving_credit', 'Sept_late_1month'] --> ['May_revolving_credit'] 0.8130021913805697
# ['Aug_not_used', 'Male'] --> ['July_not_used', 'June_not_used'] 0.8424938474159147
# ['Aug_not_used', 'July_not_used', 'Male'] --> ['June_not_used'] 0.9294117647058824
# ['Aug_not_used', 'June_not_used', 'Male'] --> ['July_not_used'] 1.0
# ['July_not_used', 'June_not_used', 'Male'] --> ['May_not_used'] 0.9207920792079208
# ['Aug_not_used', 'June_not_used', 'University'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'May_not_used', 'University'] --> ['July_not_used', 'June_not_used'] 0.9766763848396501
# ['Aug_not_used', 'July_not_used', 'University'] --> ['June_not_used'] 0.9146029035012809
# ['July_not_used', 'May_not_used', 'University'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'University'] --> ['May_not_used'] 0.938375350140056
# ['Aug_not_used', 'July_not_used', 'May_not_used', 'University'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'June_not_used', 'May_not_used', 'University'] --> ['July_not_used'] 1.0
# ['July_not_used', 'June_not_used', 'May_not_used', 'University'] --> ['Apr_not_used'] 0.939625850340136
# ['July_not_used', 'June_not_used', 'University'] --> ['May_not_used'] 0.9194683346364347
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Single'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'June_not_used', 'Single', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'Single', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.971473851030111
# ['Aug_not_used', 'July_not_used', 'Single', 'no_default'] --> ['June_not_used'] 0.9157894736842105
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'Single'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Single', 'no_default'] --> ['May_not_used'] 0.9806985294117647
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Single', 'no_default'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Single', 'no_default'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Single', 'no_default'] --> ['May_not_used'] 0.9203612479474549
# ['Aug_not_used', 'May_not_used', 'Single', 'no_default'] --> ['July_not_used', 'June_not_used'] 0.9730902777777778
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'May_not_used', 'Single'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'May_not_used', 'Single', 'no_default'] --> ['July_not_used'] 0.9780018331805683
# ['Aug_not_used', 'June_not_used', 'May_not_used', 'Single', 'no_default'] --> ['July_not_used'] 1.0
# ['July_not_used', 'May_not_used', 'Single', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'May_not_used', 'Single'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'May_not_used', 'Single', 'no_default'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'May_not_used', 'Single', 'no_default'] --> ['June_not_used'] 1.0
# ['July_not_used', 'June_not_used', 'May_not_used', 'Single', 'no_default'] --> ['Apr_not_used'] 0.9423520368946964
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Single'] --> ['no_default'] 0.8126428027418127
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'Single', 'no_default'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'May_not_used', 'Single', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'May_not_used', 'Single', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Single', 'no_default'] --> ['Aug_not_used'] 0.8703099510603589
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Single', 'no_default'] --> ['Apr_not_used'] 0.951828724353256
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Single'] --> ['May_not_used'] 0.9820493642483171
# ['Apr_not_used', 'Aug_not_used', 'May_not_used', 'Single'] --> ['July_not_used'] 0.9805825242718447
# ['Aug_not_used', 'June_not_used', 'Single'] --> ['July_not_used', 'no_default'] 0.8130841121495327
# ['Aug_not_used', 'July_not_used', 'Single'] --> ['no_default'] 0.8144519289650949
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Single'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Single'] --> ['no_default'] 0.8130841121495327
# ['Aug_not_used', 'June_not_used', 'May_not_used', 'Single'] --> ['July_not_used'] 1.0
# ['July_not_used', 'May_not_used', 'Single'] --> ['June_not_used', 'no_default'] 0.8080745341614907
# ['Apr_not_used', 'July_not_used', 'May_not_used', 'Single'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'May_not_used', 'Single'] --> ['June_not_used'] 1.0
# ['July_not_used', 'June_not_used', 'May_not_used', 'Single'] --> ['no_default'] 0.8080745341614907
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Single'] --> ['no_default'] 0.8103106411103768
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'Single'] --> ['no_default'] 0.809971098265896
# ['Aug_not_used', 'Single', 'no_default'] --> ['July_not_used'] 0.8773087071240105
# ['July_not_used', 'June_not_used', 'Single'] --> ['no_default'] 0.8133484162895928
# ['July_not_used', 'June_not_used', 'Single', 'no_default'] --> ['May_not_used'] 0.9047287899860917
# ['July_not_used', 'Single', 'no_default'] --> ['June_not_used'] 0.8795107033639143
# ['Aug_not_used', 'Female', 'July_not_used', 'Married'] --> ['June_not_used'] 0.9275618374558304
# ['Aug_not_used', 'Female', 'June_not_used', 'Married'] --> ['July_not_used'] 1.0
# ['Female', 'July_not_used', 'June_not_used', 'Married'] --> ['May_not_used'] 0.9293924466338259
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Married'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'June_not_used', 'Married', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Married'] --> ['May_not_used'] 0.9865534324133051
# ['Apr_not_used', 'July_not_used', 'Married', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.9778625954198473
# ['Aug_not_used', 'July_not_used', 'Married', 'no_default'] --> ['June_not_used'] 0.9284671532846716
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'Married'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Married', 'no_default'] --> ['May_not_used'] 0.987783595113438
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Married', 'no_default'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Married', 'no_default'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Married', 'no_default'] --> ['May_not_used'] 0.9418238993710691
# ['Aug_not_used', 'Married', 'May_not_used', 'no_default'] --> ['July_not_used', 'June_not_used'] 0.9771615008156607
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Married', 'May_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Married', 'May_not_used', 'no_default'] --> ['July_not_used'] 0.9843478260869565
# ['Aug_not_used', 'June_not_used', 'Married', 'May_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['July_not_used', 'Married', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Married', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'Married', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'Married', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['July_not_used', 'June_not_used', 'Married', 'May_not_used', 'no_default'] --> ['Apr_not_used'] 0.9370885149963424
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'Married', 'May_not_used'] --> ['no_default'] 0.812051649928264
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'Married', 'no_default'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'Married', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'Married', 'May_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Married', 'May_not_used', 'no_default'] --> ['Aug_not_used'] 0.8836846213895394
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Married', 'May_not_used', 'no_default'] --> ['Apr_not_used'] 0.9449081803005008
# ['Apr_not_used', 'Aug_not_used', 'Married', 'May_not_used'] --> ['July_not_used'] 0.9823819591261451
# ['Aug_not_used', 'June_not_used', 'Married'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'Married'] --> ['June_not_used'] 0.9276393831553974
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Married'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Married'] --> ['no_default'] 0.8132992327365729
# ['Aug_not_used', 'June_not_used', 'Married', 'May_not_used'] --> ['July_not_used'] 1.0
# ['July_not_used', 'Married', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'Married', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'Married', 'May_not_used'] --> ['June_not_used'] 1.0
# ['July_not_used', 'June_not_used', 'Married', 'May_not_used'] --> ['no_default'] 0.8060141509433962
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Married', 'May_not_used'] --> ['no_default'] 0.8082018927444795
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'Married', 'May_not_used'] --> ['no_default'] 0.8111035883547731
# ['Aug_not_used', 'Married', 'no_default'] --> ['July_not_used', 'June_not_used'] 0.8362919132149902
# ['July_not_used', 'June_not_used', 'Married', 'no_default'] --> ['May_not_used'] 0.9286684782608695
# ['July_not_used', 'June_not_used', 'Married'] --> ['May_not_used'] 0.9318681318681319
# ['July_not_used', 'Married', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.8345543345543346
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'June_not_used'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Apr_not_used', 'Graduate School', 'June_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'June_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used'] --> ['May_not_used'] 0.9856527977044476
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.9752704791344667
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'no_default'] --> ['June_not_used'] 0.9271667880553532
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used', 'no_default'] --> ['May_not_used'] 0.9859402460456942
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'June_not_used', 'no_default'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 0.9324430479183032
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'May_not_used'] --> ['July_not_used'] 0.9828326180257511
# ['Aug_not_used', 'Graduate School', 'May_not_used', 'no_default'] --> ['July_not_used', 'June_not_used'] 0.9737489745693191
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'June_not_used', 'May_not_used'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'May_not_used', 'no_default'] --> ['July_not_used'] 0.9824868651488616
# ['Apr_not_used', 'Graduate School', 'June_not_used', 'May_not_used', 'no_default'] --> ['July_not_used'] 0.9001426533523538
# ['Aug_not_used', 'Graduate School', 'June_not_used', 'May_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Graduate School', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Graduate School', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Apr_not_used'] 0.9362017804154302
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8165938864628821
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Graduate School', 'June_not_used', 'May_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Aug_not_used'] 0.8890649762282092
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Apr_not_used'] 0.945240101095198
# ['Aug_not_used', 'Graduate School', 'June_not_used'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'July_not_used'] --> ['June_not_used'] 0.9259478672985783
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'June_not_used'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used'] --> ['no_default'] 0.8144593730006398
# ['Aug_not_used', 'Graduate School', 'June_not_used', 'May_not_used'] --> ['July_not_used'] 1.0
# ['Graduate School', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Graduate School', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8130277442702051
# ['Apr_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8152454780361758
# ['Aug_not_used', 'Graduate School', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8152472527472527
# ['Graduate School', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 0.9226557152635181
# ['Graduate School', 'July_not_used', 'June_not_used'] --> ['May_not_used'] 0.9226488592097941
# ['Aug_not_used', 'Graduate School', 'no_default'] --> ['July_not_used', 'June_not_used'] 0.8309399477806788
# ['Graduate School', 'July_not_used', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.8234575442883323
# ['Apr_not_used', 'Aug_not_used', 'Female', 'June_not_used'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'Female', 'June_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used'] --> ['May_not_used'] 0.9870480302212629
# ['Apr_not_used', 'Female', 'July_not_used', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.9774956722446624
# ['Aug_not_used', 'Female', 'July_not_used', 'no_default'] --> ['June_not_used'] 0.9194776931447225
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'June_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'Female', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 0.9366863905325444
# ['Apr_not_used', 'Aug_not_used', 'Female', 'May_not_used'] --> ['July_not_used'] 0.9791220556745182
# ['Apr_not_used', 'Aug_not_used', 'Female', 'June_not_used', 'May_not_used'] --> ['July_not_used'] 1.0
# ['Female', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Female', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Female', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Apr_not_used'] 0.9390243902439024
# ['Apr_not_used', 'Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8228540185893931
# ['Apr_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Aug_not_used'] 0.8884297520661157
# ['Aug_not_used', 'Female', 'June_not_used'] --> ['July_not_used', 'no_default'] 0.8199902959728287
# ['Aug_not_used', 'Female', 'July_not_used'] --> ['no_default'] 0.8198037466547725
# ['Apr_not_used', 'Female', 'July_not_used', 'June_not_used'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'Female', 'July_not_used', 'June_not_used'] --> ['no_default'] 0.8199902959728287
# ['Aug_not_used', 'Female', 'June_not_used', 'May_not_used'] --> ['July_not_used'] 1.0
# ['Female', 'July_not_used', 'May_not_used'] --> ['June_not_used', 'no_default'] 0.8133453561767358
# ['Apr_not_used', 'Female', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'Female', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Female', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8133453561767358
# ['Apr_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8171731789676797
# ['Aug_not_used', 'Female', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8189342990170719
# ['Female', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 0.9162011173184358
# ['Female', 'July_not_used', 'June_not_used'] --> ['no_default'] 0.8170124481327801
# ['Aug_not_used', 'Female', 'no_default'] --> ['July_not_used'] 0.8794258373205741
# ['Female', 'July_not_used', 'no_default'] --> ['June_not_used'] 0.885341726618705
# ['Apr_not_used', 'Aug_not_used', 'June_not_used'] --> ['July_not_used', 'May_not_used'] 1.0
# ['Aug_not_used', 'June_not_used', 'no_default'] --> ['July_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.9749131609417213
# ['Aug_not_used', 'July_not_used', 'no_default'] --> ['June_not_used'] 0.9221446933529196
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 0.9315013938669853
# ['Aug_not_used', 'May_not_used', 'no_default'] --> ['July_not_used', 'June_not_used'] 0.9749895789912464
# ['Apr_not_used', 'Aug_not_used', 'June_not_used', 'May_not_used'] --> ['July_not_used'] 1.0
# ['July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'May_not_used', 'no_default'] --> ['June_not_used'] 1.0
# ['July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Apr_not_used'] 0.9390334572490706
# ['Apr_not_used', 'Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8120879120879121
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'May_not_used', 'no_default'] --> ['Aug_not_used'] 0.8776722090261283
# ['Apr_not_used', 'Aug_not_used', 'July_not_used'] --> ['May_not_used'] 0.9844933285250631
# ['Apr_not_used', 'Aug_not_used', 'May_not_used'] --> ['July_not_used'] 0.9816612729234089
# ['Aug_not_used', 'June_not_used'] --> ['July_not_used'] 1.0
# ['Aug_not_used', 'July_not_used'] --> ['June_not_used'] 0.9226172691962952
# ['Apr_not_used', 'July_not_used', 'June_not_used'] --> ['May_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'June_not_used'] --> ['no_default'] 0.8131476683937824
# ['Aug_not_used', 'June_not_used', 'May_not_used'] --> ['July_not_used'] 1.0
# ['July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Aug_not_used', 'July_not_used', 'May_not_used'] --> ['June_not_used'] 1.0
# ['July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8068386322735452
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.808837656099904
# ['Aug_not_used', 'July_not_used', 'June_not_used', 'May_not_used'] --> ['no_default'] 0.8104643104643104
# ['Aug_not_used', 'no_default'] --> ['July_not_used', 'June_not_used'] 0.8189823874755382
# ['July_not_used', 'no_default'] --> ['June_not_used', 'May_not_used'] 0.8144111413866182
# ['July_not_used', 'June_not_used', 'no_default'] --> ['May_not_used'] 0.9155888359428183
# ['July_not_used', 'June_not_used'] --> ['May_not_used'] 0.9204859193815571
# ['July_late_2months', 'June_revolving_credit'] --> ['May_revolving_credit'] 0.9605911330049262
# ['Apr_revolving_credit', 'July_late_2months'] --> ['May_revolving_credit'] 0.8187168922895821
# ['July_late_2months', 'May_revolving_credit'] --> ['Apr_revolving_credit'] 0.8045112781954887
# ['Aug_late_2months', 'July_revolving_credit'] --> ['June_revolving_credit'] 0.9856759176365264
# ['Apr_revolving_credit', 'Aug_late_2months', 'June_revolving_credit'] --> ['May_revolving_credit'] 0.9236393176279447
# ['Apr_not_used', 'July_not_used', 'Male'] --> ['June_not_used', 'May_not_used'] 0.9722222222222222
# ['July_not_used', 'Male', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'June_not_used', 'Male'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'June_not_used', 'Male'] --> ['May_not_used'] 1.0
# ['Apr_not_used', 'July_not_used', 'Male', 'May_not_used'] --> ['June_not_used'] 1.0
# ['Apr_not_used', 'June_not_used', 'Male', 'May_not_used'] --> ['July_not_used'] 0.8413461538461539
# ['July_not_used', 'June_not_used', 'Male', 'May_not_used'] --> ['Apr_not_used'] 0.9408602150537635
# ['June_not_used', 'Male', 'May_not_used'] --> ['Apr_not_used'] 0.9278810408921933
# ...
# ['Aug_revolving_credit', 'Female', 'July_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit'] --> ['no_default'] 0.9007133498325811
# ['Aug_revolving_credit', 'Female', 'July_revolving_credit', 'June_revolving_credit'] --> ['no_default'] 0.8709505399280096
# ['Aug_revolving_credit', 'Female', 'July_revolving_credit', 'Sept_revolving_credit'] --> ['no_default'] 0.8937558247903076
# ['Apr_revolving_credit', 'Female', 'June_revolving_credit', 'May_revolving_credit'] --> ['no_default'] 0.8472204224439549
# ['Aug_revolving_credit', 'Female', 'June_revolving_credit'] --> ['July_revolving_credit'] 0.9484132001517259
# ['Aug_revolving_credit', 'Female', 'Sept_revolving_credit'] --> ['no_default'] 0.8829204383039543
# ['Female', 'July_revolving_credit', 'June_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9185850645704661
# ['Female', 'Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9649830773236137
# ['Female', 'June_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['Apr_revolving_credit'] 0.8907356948228883
# ['Female', 'July_revolving_credit', 'May_revolving_credit'] --> ['June_revolving_credit'] 0.9563913532425341
# ['Female', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit'] --> ['no_default'] 0.854977789391168
# ['Aug_revolving_credit', 'Female', 'July_revolving_credit'] --> ['June_revolving_credit'] 0.9036260691482954
# ['Female', 'June_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9090909090909091
# ['Female', 'July_revolving_credit', 'June_revolving_credit'] --> ['May_revolving_credit'] 0.9087023625786537
# ['Apr_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9641159926292309
# ['Apr_revolving_credit', 'July_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['Aug_revolving_credit'] 0.9926449240298074
# ['Apr_revolving_credit', 'July_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.9603903004540624
# ['Apr_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['Aug_revolving_credit'] 0.9881980426021877
# ['Apr_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9146195602171313
# ['Apr_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9843480028458177
# ['July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['Aug_revolving_credit'] 0.9917691667437344
# ['July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['Apr_revolving_credit'] 0.9119346848912944
# ['July_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9913319849754406
# ['June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9866548915709941
# ['Apr_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['Aug_revolving_credit'] 0.9924211802748585
# ['Apr_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9291821748315059
# ['Apr_revolving_credit', 'July_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9926271278325924
# ['Apr_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9881656804733728
# ['July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.992008303061754
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'Sept_revolving_credit'] --> ['May_revolving_credit'] 0.9578819574150168
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9590555887627017
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit'] --> ['May_revolving_credit'] 0.9678601635184663
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['July_revolving_credit'] 0.939974340175953
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9454920447849146
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9541871921182266
# ['Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9256433823529412
# ['Aug_revolving_credit', 'July_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.960973282442748
# ['Aug_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9512609804477189
# ['Aug_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9514697726012202
# ['Aug_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.9493013595166163
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit'] --> ['no_default'] 0.8681390977443609
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit'] --> ['May_revolving_credit'] 0.9672050423478432
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9674277335567658
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['June_revolving_credit'] 0.9574924441844594
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.9594889373636647
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9611548556430446
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['July_revolving_credit'] 0.9535877269637829
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9577975943591871
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9692908400168848
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9452762003097573
# ['Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['no_default'] 0.8912719134651249
# ['Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['Apr_revolving_credit'] 0.9171879654453381
# ['Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9285922471582629
# ['Aug_revolving_credit', 'July_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.9620533467539003
# ['Aug_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9505718547986076
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['no_default'] 0.8955299867630587
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['Sept_revolving_credit'] 0.9521489661145394
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9689324666740112
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.9606772255598034
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9575394665215025
# ['Apr_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9924396298803881
# ['Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['Apr_revolving_credit'] 0.9201715840133919
# ['Apr_revolving_credit', 'June_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9642476933995742
# ['July_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9909026673732556
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit'] --> ['May_revolving_credit'] 0.9647293498957294
# ['Aug_revolving_credit', 'July_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.9174614493270346
# ['Apr_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['Aug_revolving_credit'] 0.9844821364128473
# ['June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['Aug_revolving_credit'] 0.986428882122662
# ['Aug_revolving_credit', 'June_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9518810148731408
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'June_revolving_credit', 'May_revolving_credit'] --> ['July_revolving_credit'] 0.9552882025498294
# ['Aug_revolving_credit', 'June_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['July_revolving_credit'] 0.9457624129111915
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'Sept_revolving_credit'] --> ['May_revolving_credit'] 0.9495301079011487
# ['July_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.9615418541060246
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit', 'May_revolving_credit'] --> ['June_revolving_credit'] 0.953234187421609
# ['Aug_revolving_credit', 'July_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['June_revolving_credit'] 0.9592128801431127
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'July_revolving_credit'] --> ['May_revolving_credit'] 0.954424967935015
# ['Apr_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.8985615079365079
# ['Apr_revolving_credit', 'Aug_revolving_credit', 'May_revolving_credit'] --> ['July_revolving_credit'] 0.9421794547142737
# ['Aug_revolving_credit', 'May_revolving_credit', 'Sept_revolving_credit'] --> ['June_revolving_credit'] 0.9455470313542361
# ['Aug_revolving_credit', 'Sept_revolving_credit', 'no_default'] --> ['July_revolving_credit'] 0.9023566315450816
# ['Apr_revolving_credit', 'July_revolving_credit', 'June_revolving_credit'] --> ['May_revolving_credit'] 0.9593562689876016
# ['Apr_revolving_credit', 'July_revolving_credit', 'May_revolving_credit'] --> ['June_revolving_credit'] 0.9554338048900155
# ['July_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit'] --> ['Aug_revolving_credit'] 0.9909362975630611
# ['Apr_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit'] --> ['no_default'] 0.8508216364258816
# ['Aug_revolving_credit', 'July_revolving_credit', 'May_revolving_credit'] --> ['June_revolving_credit'] 0.9551334534141149
# ['Aug_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit'] --> ['July_revolving_credit'] 0.9469684588985128
# ['Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit'] --> ['no_default'] 0.8632779015943768
# ['Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit', 'Sept_revolving_credit'] --> ['no_default'] 0.888169816205022
# ['Aug_revolving_credit', 'July_revolving_credit', 'June_revolving_credit'] --> ['no_default'] 0.8581118384730657
# ['Apr_revolving_credit', 'June_revolving_credit', 'May_revolving_credit'] --> ['no_default'] 0.83543428132206
# ['Aug_revolving_credit', 'June_revolving_credit', 'May_revolving_credit'] --> ['July_revolving_credit'] 0.9482240104039665
# ['Aug_revolving_credit', 'July_revolving_credit', 'Sept_revolving_credit'] --> ['no_default'] 0.8816502946954813
# ['Aug_revolving_credit', 'Sept_revolving_credit'] --> ['no_default'] 0.8719405287888351
# ['July_revolving_credit', 'June_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9169751009421265
# ['Aug_revolving_credit', 'July_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.913441356729074
# ['June_revolving_credit', 'May_revolving_credit', 'no_default'] --> ['Apr_revolving_credit'] 0.8901719901719902
# ['Sept_revolving_credit', 'no_default'] --> ['Aug_revolving_credit'] 0.9676239396061951
# ['July_revolving_credit', 'May_revolving_credit'] --> ['June_revolving_credit'] 0.9570656599304168
# ['July_revolving_credit', 'June_revolving_credit', 'May_revolving_credit'] --> ['no_default'] 0.8431433212158713
# ['Aug_revolving_credit', 'June_revolving_credit'] --> ['July_revolving_credit'] 0.9492400988245864
# ['June_revolving_credit', 'no_default'] --> ['May_revolving_credit'] 0.9085497432844706
# ['July_revolving_credit', 'June_revolving_credit'] --> ['May_revolving_credit'] 0.9069800070150824
# ['Aug_revolving_credit', 'July_revolving_credit'] --> ['June_revolving_credit'] 0.9008810572687225
# ['Apr_revolving_credit', 'Female', 'June_revolving_credit', 'Single'] --> ['May_revolving_credit'] 0.95923537540304
# ['Apr_revolving_credit', 'Female', 'May_revolving_credit', 'Single'] --> ['June_revolving_credit'] 0.8848523475674527
# ['Female', 'June_revolving_credit', 'May_revolving_credit', 'Single'] --> ['no_default'] 0.844903988183161
# ['Apr_revolving_credit', 'June_revolving_credit', 'Single'] --> ['May_revolving_credit'] 0.9594828735172598
# ['Apr_revolving_credit', 'May_revolving_credit', 'Single'] --> ['June_revolving_credit'] 0.8824466781073793
# ['June_revolving_credit', 'May_revolving_credit', 'Single'] --> ['no_default'] 0.8331306251520312
# ['Apr_revolving_credit', 'Female', 'June_revolving_credit'] --> ['May_revolving_credit'] 0.9593485827946295
# ['Apr_revolving_credit', 'Female', 'May_revolving_credit'] --> ['June_revolving_credit'] 0.8820436621328152
# ['Female', 'June_revolving_credit', 'May_revolving_credit'] --> ['no_default'] 0.8373260323979009
# ['Apr_revolving_credit', 'June_revolving_credit'] --> ['May_revolving_credit'] 0.9604311235789162
# ['Apr_revolving_credit', 'May_revolving_credit'] --> ['June_revolving_credit'] 0.8829317950458093
# ['June_revolving_credit', 'May_revolving_credit'] --> ['no_default'] 0.8236087689713322
# ['Female', 'May_revolving_credit', 'Single', 'no_default'] --> ['June_revolving_credit'] 0.8862328463922089
# ['May_revolving_credit', 'Single', 'no_default'] --> ['June_revolving_credit'] 0.8869610255082222
# ['Female', 'May_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.8850838056191969
# ['May_revolving_credit', 'no_default'] --> ['June_revolving_credit'] 0.8878708551483421
# ['Female', 'May_revolving_credit', 'Single'] --> ['no_default'] 0.8340409820934096
# ['Female', 'Single'] --> ['no_default'] 0.8025531914893617
# ['Female', 'May_revolving_credit'] --> ['no_default'] 0.8244358286111939
